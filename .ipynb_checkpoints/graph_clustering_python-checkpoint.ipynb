# %% [markdown]
# # Title: Network Visualization
# # Author: Rafael S. de Souza

# %% [markdown]
# ## Introduction
#
# In this Jupyter Notebook, we will explore the implementation of a network visualization for the Iris dataset using Python. The main steps are as follows:
#
# 1. Import required libraries
# 2. Prepare the data
# 3. Calculate dissimilarity matrix using Manhattan distance
# 4. Create an undirected graph from the dissimilarity matrix
# 5. Compute minimum spanning tree using Prim's algorithm
# 6. Create a layout for the graph
# 7. Prepare data for plotting
# 8. Plot the network with matplotlib

# %% [markdown]
# ### Import Required Libraries

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Prepare the data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")
df["ID"] = df.index

# %% [markdown]
# ### Calculate dissimilarity matrix using Manhattan distance

# %%
dissMat = squareform(pdist(df.drop(columns=["species", "ID"]), metric="cityblock"))

# %% [markdown]
# ### Create an undirected graph from the dissimilarity matrix

# %%
undirected_graph = nx.from_numpy_matrix(dissMat)

# %% [markdown]
# ### Compute minimum spanning tree using Prim's algorithm

# %%
mst_graph = nx.minimum_spanning_tree(undirected_graph, algorithm="prim")

# %% [markdown]
# ### Create a layout for the graph

# %%
pos = nx.spring_layout(mst_graph)

# %% [markdown]
# ### Prepare data for plotting

# %%
node_list = list(mst_graph.nodes())
node_color = df.loc[node_list, "species"].map({"setosa": "red", "versicolor": "green", "virginica": "blue"})

# %% [markdown]
# ### Plot the network with matplotlib

# %%
plt.figure(figsize=(10, 8))
nx.draw_networkx(mst_graph, pos, node_color=node_color, node_size=100, with_labels=False, edge_color="grey")
plt.title("Iris Minimum Spanning Tree")
plt.axis("off")
plt.show()
